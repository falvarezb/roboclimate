# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
london_df = pd.read_csv("london_weather_historical_data.csv")
london_df['parsed_dt'] = london_df['dt_iso'].apply(lambda x: x[:19])
london_df.set_index(pd.DatetimeIndex(london_df['parsed_dt']), inplace=True)

# %%
london_df.head()
# Out:
#                             dt                         dt_iso  timezone  \
# parsed_dt
# 2000-01-01 00:00:00  946684800  2000-01-01 00:00:00 +0000 UTC         0
# 2000-01-01 01:00:00  946688400  2000-01-01 01:00:00 +0000 UTC         0
# 2000-01-01 02:00:00  946692000  2000-01-01 02:00:00 +0000 UTC         0
# 2000-01-01 03:00:00  946695600  2000-01-01 03:00:00 +0000 UTC         0
# 2000-01-01 04:00:00  946699200  2000-01-01 04:00:00 +0000 UTC         0
#
#                      city_id city_name       lat      lon  temp  temp_min  \
# parsed_dt
# 2000-01-01 00:00:00  2643743    London  51.50853 -0.12574  7.18       6.5
# 2000-01-01 01:00:00  2643743    London  51.50853 -0.12574  7.35       6.9
# 2000-01-01 02:00:00  2643743    London  51.50853 -0.12574  8.06       7.3
# 2000-01-01 03:00:00  2643743    London  51.50853 -0.12574  8.26       7.4
# 2000-01-01 04:00:00  2643743    London  51.50853 -0.12574  8.52       7.9
#
# ...

# %%
london_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 174938 entries, 2000-01-01 00:00:00 to 2019-12-12 23:00:00
# Data columns (total 34 columns):
# dt                     174938 non-null int64
# dt_iso                 174938 non-null object
# timezone               174938 non-null int64
# city_id                174938 non-null int64
# city_name              174938 non-null object
# lat                    174938 non-null float64
# lon                    174938 non-null float64
# temp                   174938 non-null float64
# temp_min               174938 non-null float64
# temp_max               174938 non-null float64
# pressure               174938 non-null float64
# sea_level              0 non-null float64
# grnd_level             0 non-null float64
# humidity               174938 non-null int64
# wind_speed             174938 non-null float64
# wind_deg               174938 non-null int64
# rain_1h                6416 non-null float64
# ...

# %%
london_df['temp'].head()
# Out:
# parsed_dt
# 2000-01-01 00:00:00    7.18
# 2000-01-01 01:00:00    7.35
# 2000-01-01 02:00:00    8.06
# 2000-01-01 03:00:00    8.26
# 2000-01-01 04:00:00    8.52
# Name: temp, dtype: float64

# %%
plt.plot(london_df['temp']['2019-12-01':'2019-12-12'], label='2019')
# plt.plot(london_df['temp']['2018-12-01':'2018-12-12'], label='2018')
plt.title("London temperature")
plt.legend()
plt.show()

# %%
london_df['temp']['2019-12-01':]
# Out:
# parsed_dt
# 2019-12-01 00:00:00    3.19
# 2019-12-01 01:00:00    3.21
# 2019-12-01 02:00:00    2.89
# 2019-12-01 03:00:00    2.46
# 2019-12-01 04:00:00    2.98
# 2019-12-01 05:00:00    3.33
# 2019-12-01 06:00:00    3.65
# 2019-12-01 07:00:00    3.87
# 2019-12-01 08:00:00    4.22
# 2019-12-01 09:00:00    4.42
# 2019-12-01 10:00:00    4.28
# 2019-12-01 11:00:00    5.28
# 2019-12-01 12:00:00    6.21
# 2019-12-01 13:00:00    6.78
# 2019-12-01 14:00:00    6.81
# 2019-12-01 15:00:00    6.68
# 2019-12-01 16:00:00    6.19
# 2019-12-01 17:00:00    5.97
# 2019-12-01 18:00:00    5.06
# 2019-12-01 19:00:00    3.91
# 2019-12-01 20:00:00    3.13
# 2019-12-01 21:00:00    2.83
# 2019-12-01 22:00:00    2.44
# 2019-12-01 23:00:00    1.73
# 2019-12-02 00:00:00    1.11
# 2019-12-02 01:00:00    0.88
# 2019-12-02 02:00:00    0.46
# 2019-12-02 03:00:00    0.42
# 2019-12-02 04:00:00    0.19
# 2019-12-02 05:00:00    0.00
#                        ...
# 2019-12-11 20:00:00    3.76
# ...

# %%
london_df['temp']['2019-01-01':].describe()
# Out:
# count    8340.000000
# mean       11.820144
# std         6.079492
# min        -4.020000
# 25%         7.470000
# 50%        11.300000
# 75%        16.110000
# max        36.610000
# Name: temp, dtype: float64

# %%
london_df['temp']['2018-01-01':'2018-12-31'].describe()
# Out:
# count    8762.000000
# mean       11.926793
# std         6.617931
# min        -6.200000
# 25%         7.000000
# 50%        11.210000
# 75%        16.690000
# max        33.700000
# Name: temp, dtype: float64

# %%
london_df['temp']['2017-01-01':'2017-12-31'].describe()
# Out:
# count    8761.000000
# mean       11.763353
# std         5.899253
# min        -4.710000
# 25%         7.660000
# 50%        11.870000
# 75%        15.870000
# max        31.640000
# Name: temp, dtype: float64

# %%
london_df[['temp']].resample('Y').mean()
# Out:
#                  temp
# parsed_dt
# 2000-12-31  11.306506
# 2001-12-31  10.928856
# 2002-12-31  11.623682
# 2003-12-31  11.581478
# 2004-12-31  11.419225
# 2005-12-31  11.342956
# 2006-12-31  11.821936
# 2007-12-31  11.511014
# 2008-12-31  11.112175
# 2009-12-31  11.308089
# 2010-12-31   9.964821
# 2011-12-31  11.684691
# 2012-12-31  10.832230
# 2013-12-31  10.559595
# 2014-12-31  12.201511
# 2015-12-31  11.495582
# 2016-12-31  11.473712
# 2017-12-31  11.763353
# 2018-12-31  11.926793
# 2019-12-31  11.820144

# %%
plt.plot(london_df[['temp']].resample('Y').mean(), label="avg")
plt.plot(london_df[['temp']].resample('Y').max(), label="max")
plt.plot(london_df[['temp']].resample('Y').min(), label="min")
plt.title("London annual temp")
plt.legend()
plt.show()

# %%
london_df[['temp']].resample('M').mean()
# Out:
#                  temp
# parsed_dt
# 2000-01-31   5.721962
# 2000-02-29   7.170460
# 2000-03-31   8.153777
# 2000-04-30   8.728514
# 2000-05-31  13.132433
# 2000-06-30  16.405194
# 2000-07-31  16.310981
# 2000-08-31  17.930968
# 2000-09-30  15.929820
# 2000-10-31  11.464449
# 2000-11-30   7.946097
# 2000-12-31   6.638685
# 2001-01-31   4.316048
# 2001-02-28   5.535193
# 2001-03-31   6.245538
# 2001-04-30   8.457319
# 2001-05-31  13.302836
# 2001-06-30  15.647819
# 2001-07-31  18.730202
# 2001-08-31  18.072742
# 2001-09-30  14.015736
# 2001-10-31  14.132016
# 2001-11-30   7.976333
# 2001-12-31   4.278295
# 2002-01-31   6.693360
# 2002-02-28   7.914955
# 2002-03-31   8.429892
# 2002-04-30  10.069764
# 2002-05-31  12.515215
# 2002-06-30  15.547681
# ...               ...
# 2017-07-31  18.511331
# 2017-08-31  17.174839
# 2017-09-30  14.426111
# 2017-10-31  13.373185
# 2017-11-30   7.844681
# 2017-12-31   5.931423
# 2018-01-31   6.547164
# 2018-02-28   3.405580
# 2018-03-31   5.869704
# ...

# %%
plt.plot(london_df[['temp']].resample('M').mean(), label="avg")
# plt.plot(london_df[['temp']].resample('M').max(), label="max")
# plt.plot(london_df[['temp']].resample('M').min(), label="min")
plt.title("London monthly temp")
plt.legend()
plt.show()

# %%
london_df[['temp']].resample('M').mean().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 240 entries, 2000-01-31 to 2019-12-31
# Freq: M
# Data columns (total 1 columns):
# temp    240 non-null float64
# dtypes: float64(1)
# memory usage: 3.8 KB

# %%
london_df[['temp']].resample('M').mean()['2018-01-31':'2018-12-31']
# Out:
#                  temp
# parsed_dt
# 2018-01-31   6.547164
# 2018-02-28   3.405580
# 2018-03-31   5.869704
# 2018-04-30  11.191708
# 2018-05-31  14.570417
# 2018-06-30  17.491944
# 2018-07-31  21.332903
# 2018-08-31  18.504234
# 2018-09-30  15.077375
# 2018-10-31  11.891962
# 2018-11-30   8.793190
# 2018-12-31   7.786832

# %%
plt.plot(london_df[['temp']].resample('M').mean()['2018-01-31':'2018-12-31'])
plt.title("London monthly temp 2018")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
london_df[['temp']].resample('M').mean()['2019-01-31':'2019-12-31']
# Out:
#                  temp
# parsed_dt
# 2019-01-31   4.591734
# 2019-02-28   7.372634
# 2019-03-31   9.009328
# 2019-04-30   9.966472
# 2019-05-31  12.894993
# 2019-06-30  16.197458
# 2019-07-31  19.512865
# 2019-08-31  18.577667
# 2019-09-30  15.422296
# 2019-10-31  11.306512
# 2019-11-30   7.028605
# 2019-12-31   5.996207

# %%
plt.plot(london_df[['temp']].resample('M').mean()['2019-01-31':'2019-12-31'])
plt.title("London monthly temp 2019")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(london_df[['temp']].resample('D').mean()['2019-12-01':'2019-12-31'])
# plt.plot(london_df[['temp']].resample('M').max(), label="max")
# plt.plot(london_df[['temp']].resample('M').min(), label="min")
plt.title("Dec temp")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
london_df[['temp']].resample('D').mean()['2019-12-01':'2019-12-31']
# Out:
#                  temp
# parsed_dt
# 2019-12-01   4.230000
# 2019-12-02   1.979583
# 2019-12-03   4.125000
# 2019-12-04   2.884167
# 2019-12-05   5.174167
# 2019-12-06  11.012917
# 2019-12-07   9.289167
# 2019-12-08   9.062917
# 2019-12-09   6.855000
# 2019-12-10   6.761667
# 2019-12-11   5.132917
# 2019-12-12   5.489231
